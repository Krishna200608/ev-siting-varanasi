# %% [markdown]
# # 01. GIS Data Exploration & Spatial Processing
#
# **Pipeline A: GIS Preparation (Milestone 2)**
# Exploratory notebook for loading raw spatial layers for Varanasi (OSM roads/POIs, Census population data, Bhuvan land use, power substations), inspecting coordinate reference systems (CRS), generating candidate site buffers, and rasterizing criteria.

# %%
import sys
from pathlib import Path

# Ensure src is on Python path
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print(f"Project Root: {PROJECT_ROOT}")

# %%
# To be implemented in Milestone 2
# from src.gis.build_decision_matrix import load_raw_gis_layers, create_candidate_buffers
