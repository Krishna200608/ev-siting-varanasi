# %% [markdown]
# # 03. ML Demand Modeling & SHAP Interpretability
#
# **Pipeline B: Machine Learning Demand Forecasting (Milestone 4)**
# Exploratory notebook for inspecting external hourly EV charging datasets, training and benchmarking gradient-boosted decision trees (XGBoost), computing Shapley feature attributions (SHAP), and inferring relative demand potentials for candidate site feature vectors.

# %%
import sys
from pathlib import Path

# Ensure src is on Python path
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print(f"Project Root: {PROJECT_ROOT}")

# %%
# To be implemented in Milestone 4
# from src.ml.train_demand_model import preprocess_demand_data, train_xgboost_regressor
# from src.ml.explain import compute_shap_values
